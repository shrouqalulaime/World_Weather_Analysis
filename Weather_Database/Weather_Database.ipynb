# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + " ".join(city.split())
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 1 | yangambi
# Processing Record 6 of Set 1 | cayenne
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | romny
# Processing Record 9 of Set 1 | indramayu
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | sabang
# Processing Record 12 of Set 1 | pacific grove
# Processing Record 13 of Set 1 | katherine
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | vardo
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | coachella
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | dalvik
# Processing Record 21 of Set 1 | plettenberg bay
# Processing Record 22 of Set 1 | bud
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | ajdabiya
# Processing Record 33 of Set 1 | vao
# Processing Record 34 of Set 1 | kisangani
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | prescott
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | chalus
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | riyadh
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | berlevag
# Processing Record 46 of Set 1 | owerri
# Processing Record 47 of Set 1 | lazaro cardenas
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | san cristobal
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | pimenta bueno
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | provideniya
# Processing Record 8 of Set 2 | flin flon
# Processing Record 9 of Set 2 | cotonou
# Processing Record 10 of Set 2 | rorvik
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | piacabucu
# Processing Record 14 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 2 | beipiao
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | tilichiki
# Processing Record 18 of Set 2 | padang
# Processing Record 19 of Set 2 | marang
# Processing Record 20 of Set 2 | bartica
# Processing Record 21 of Set 2 | ugoofaaru
# Processing Record 22 of Set 2 | eureka
# Processing Record 23 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | san policarpo
# Processing Record 26 of Set 2 | olinda
# Processing Record 27 of Set 2 | aracati
# Processing Record 28 of Set 2 | udachnyy
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | bubaque
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | najran
# Processing Record 35 of Set 2 | canmore
# Processing Record 36 of Set 2 | puerto barrios
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | geraldton
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | aswan
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | denpasar
# Processing Record 45 of Set 2 | dwarka
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | ostrowiec swietokrzyski
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | hami
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | paringao
# Processing Record 6 of Set 3 | svetlaya
# Processing Record 7 of Set 3 | hohoe
# Processing Record 8 of Set 3 | rehoboth
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 3 | kindu
# Processing Record 12 of Set 3 | garissa
# Processing Record 13 of Set 3 | pochutla
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | rankweil
# Processing Record 16 of Set 3 | mogadishu
# Processing Record 17 of Set 3 | praya
# Processing Record 18 of Set 3 | pandaria
# Processing Record 19 of Set 3 | axim
# Processing Record 20 of Set 3 | chimbarongo
# Processing Record 21 of Set 3 | roma
# Processing Record 22 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 3 | talaya
# Processing Record 24 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | bulungu
# Processing Record 27 of Set 3 | acarau
# Processing Record 28 of Set 3 | palghar
# Processing Record 29 of Set 3 | biak
# Processing Record 30 of Set 3 | gasa
# Processing Record 31 of Set 3 | cap malheureux
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | jhelum
# Processing Record 35 of Set 3 | skibbereen
# Processing Record 36 of Set 3 | labranzagrande
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | hovd
# Processing Record 39 of Set 3 | tunceli
# Processing Record 40 of Set 3 | ribeira brava
# Processing Record 41 of Set 3 | moose factory
# Processing Record 42 of Set 3 | auray
# Processing Record 43 of Set 3 | yumen
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | salalah
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | kununurra
# Processing Record 49 of Set 3 | mehamn
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | susaki
# Processing Record 2 of Set 4 | jeremie
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | tiarei
# Processing Record 10 of Set 4 | denison
# Processing Record 11 of Set 4 | tampere
# Processing Record 12 of Set 4 | gigmoto
# Processing Record 13 of Set 4 | namatanai
# Processing Record 14 of Set 4 | carmen
# Processing Record 15 of Set 4 | deputatskiy
# Processing Record 16 of Set 4 | arys
# Processing Record 17 of Set 4 | rjukan
# Processing Record 18 of Set 4 | comodoro rivadavia
# Processing Record 19 of Set 4 | warwick
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | lasa
# Processing Record 22 of Set 4 | uruzgan
# Processing Record 23 of Set 4 | shekhupura
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | archidona
# Processing Record 28 of Set 4 | anadyr
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | aljezur
# Processing Record 33 of Set 4 | leshukonskoye
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | lima
# Processing Record 36 of Set 4 | sao joao da barra
# Processing Record 37 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 4 | tuy hoa
# Processing Record 39 of Set 4 | metu
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | jinji
# Processing Record 42 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | richards bay
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | taksimo
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | nanpiao
# Processing Record 50 of Set 4 | calderitas
# Processing Record 1 of Set 5 | nhulunbuy
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | kirakira
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | coulommiers
# Processing Record 8 of Set 5 | hilo
# Processing Record 9 of Set 5 | saint-leu
# Processing Record 10 of Set 5 | quatre cocos
# Processing Record 11 of Set 5 | minab
# Processing Record 12 of Set 5 | aksu
# Processing Record 13 of Set 5 | barra patuca
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | astghadzor
# Processing Record 17 of Set 5 | bilibino
# Processing Record 18 of Set 5 | coihaique
# Processing Record 19 of Set 5 | lompoc
# Processing Record 20 of Set 5 | mariinsk
# Processing Record 21 of Set 5 | meghraj
# Processing Record 22 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | nylstroom
# City not found. Skipping...
# Processing Record 25 of Set 5 | falmouth
# Processing Record 26 of Set 5 | dickinson
# Processing Record 27 of Set 5 | barrow
# Processing Record 28 of Set 5 | inuvik
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | broken hill
# Processing Record 31 of Set 5 | ahipara
# Processing Record 32 of Set 5 | leh
# Processing Record 33 of Set 5 | rocha
# Processing Record 34 of Set 5 | chapleau
# Processing Record 35 of Set 5 | sechura
# Processing Record 36 of Set 5 | verkhnevilyuysk
# Processing Record 37 of Set 5 | yamethin
# Processing Record 38 of Set 5 | suntar
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | koyilandi
# City not found. Skipping...
# Processing Record 42 of Set 5 | alenquer
# Processing Record 43 of Set 5 | yarega
# Processing Record 44 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 5 | arman
# Processing Record 46 of Set 5 | rundu
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | okha
# Processing Record 49 of Set 5 | yellowknife
# Processing Record 50 of Set 5 | yar-sale
# Processing Record 1 of Set 6 | shimoda
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | mao
# Processing Record 4 of Set 6 | sistranda
# Processing Record 5 of Set 6 | mayumba
# Processing Record 6 of Set 6 | talara
# Processing Record 7 of Set 6 | biharamulo
# Processing Record 8 of Set 6 | tuatapere
# Processing Record 9 of Set 6 | kalawit
# Processing Record 10 of Set 6 | bambous virieux
# Processing Record 11 of Set 6 | dondo
# Processing Record 12 of Set 6 | gisborne
# Processing Record 13 of Set 6 | nemuro
# Processing Record 14 of Set 6 | morrinhos
# Processing Record 15 of Set 6 | tambura
# Processing Record 16 of Set 6 | omsukchan
# Processing Record 17 of Set 6 | kunming
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | rognan
# Processing Record 21 of Set 6 | emba
# Processing Record 22 of Set 6 | soure
# Processing Record 23 of Set 6 | oxbow
# Processing Record 24 of Set 6 | salinopolis
# Processing Record 25 of Set 6 | henties bay
# Processing Record 26 of Set 6 | kiomboi
# Processing Record 27 of Set 6 | morondava
# Processing Record 28 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 6 | kazachinskoye
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 6 | kuusamo
# Processing Record 33 of Set 6 | vinh
# Processing Record 34 of Set 6 | gualaquiza
# Processing Record 35 of Set 6 | hlotse
# Processing Record 36 of Set 6 | puquio
# Processing Record 37 of Set 6 | netanya
# Processing Record 38 of Set 6 | yokadouma
# Processing Record 39 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 6 | potsdam
# Processing Record 41 of Set 6 | manicore
# Processing Record 42 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 6 | srednekolymsk
# Processing Record 44 of Set 6 | sorong
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | port arthur
# Processing Record 47 of Set 6 | karasjok
# Processing Record 48 of Set 6 | westport
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | port lincoln
# Processing Record 1 of Set 7 | pasni
# Processing Record 2 of Set 7 | rio gallegos
# Processing Record 3 of Set 7 | chandla
# Processing Record 4 of Set 7 | sarangani
# Processing Record 5 of Set 7 | mmabatho
# Processing Record 6 of Set 7 | vung tau
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | xai-xai
# Processing Record 9 of Set 7 | yerbogachen
# Processing Record 10 of Set 7 | shebunino
# Processing Record 11 of Set 7 | boa vista
# Processing Record 12 of Set 7 | pimentel
# Processing Record 13 of Set 7 | rumonge
# Processing Record 14 of Set 7 | bella union
# Processing Record 15 of Set 7 | rosetta
# Processing Record 16 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 7 | roanoke
# Processing Record 18 of Set 7 | yeppoon
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | guerrero negro
# Processing Record 21 of Set 7 | galesong
# Processing Record 22 of Set 7 | camacupa
# Processing Record 23 of Set 7 | salgado
# Processing Record 24 of Set 7 | grafton
# Processing Record 25 of Set 7 | chor
# Processing Record 26 of Set 7 | sigli
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | egvekinot
# Processing Record 29 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 7 | niquero
# Processing Record 31 of Set 7 | behshahr
# Processing Record 32 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | tabuk
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | golden
# Processing Record 38 of Set 7 | ganzhou
# Processing Record 39 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 40 of Set 7 | aden
# Processing Record 41 of Set 7 | bainbridge
# Processing Record 42 of Set 7 | kristiinankaupunki
# Processing Record 43 of Set 7 | mangai
# Processing Record 44 of Set 7 | esperance
# Processing Record 45 of Set 7 | faya
# Processing Record 46 of Set 7 | katobu
# Processing Record 47 of Set 7 | sabha
# Processing Record 48 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 49 of Set 7 | ocos
# Processing Record 50 of Set 7 | eydhafushi
# Processing Record 1 of Set 8 | leningradskiy
# Processing Record 2 of Set 8 | itarema
# Processing Record 3 of Set 8 | kruisfontein
# Processing Record 4 of Set 8 | mirador
# Processing Record 5 of Set 8 | atherton
# Processing Record 6 of Set 8 | villanueva de la serena
# Processing Record 7 of Set 8 | pucallpa
# Processing Record 8 of Set 8 | yarmouth
# Processing Record 9 of Set 8 | bani
# Processing Record 10 of Set 8 | santa isabel
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 8 | gamba
# Processing Record 15 of Set 8 | sola
# Processing Record 16 of Set 8 | kaduy
# Processing Record 17 of Set 8 | tablas
# Processing Record 18 of Set 8 | beyneu
# Processing Record 19 of Set 8 | prince rupert
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | sakakah
# Processing Record 22 of Set 8 | aykhal
# Processing Record 23 of Set 8 | severo-kurilsk
# Processing Record 24 of Set 8 | suez
# Processing Record 25 of Set 8 | labuhan
# Processing Record 26 of Set 8 | liverpool
# Processing Record 27 of Set 8 | atar
# Processing Record 28 of Set 8 | ust-nera
# Processing Record 29 of Set 8 | hastings
# Processing Record 30 of Set 8 | mitsamiouli
# Processing Record 31 of Set 8 | klaksvik
# Processing Record 32 of Set 8 | mongu
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | sawtell
# Processing Record 35 of Set 8 | iralaya
# Processing Record 36 of Set 8 | tahoua
# Processing Record 37 of Set 8 | bonavista
# Processing Record 38 of Set 8 | kralendijk
# Processing Record 39 of Set 8 | kalabo
# Processing Record 40 of Set 8 | metapan
# Processing Record 41 of Set 8 | fort nelson
# Processing Record 42 of Set 8 | nyaunglebin
# Processing Record 43 of Set 8 | yakuplu
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | jambi
# Processing Record 46 of Set 8 | nikolskoye
# Processing Record 47 of Set 8 | katsuura
# Processing Record 48 of Set 8 | sulina
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | bara
# Processing Record 1 of Set 9 | marzuq
# Processing Record 2 of Set 9 | boueni
# Processing Record 3 of Set 9 | evensk
# Processing Record 4 of Set 9 | bentiu
# Processing Record 5 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | grand gaube
# Processing Record 8 of Set 9 | saint-georges
# Processing Record 9 of Set 9 | manggar
# Processing Record 10 of Set 9 | nabire
# Processing Record 11 of Set 9 | sorsk
# Processing Record 12 of Set 9 | clermont
# Processing Record 13 of Set 9 | ahuimanu
# Processing Record 14 of Set 9 | olafsvik
# Processing Record 15 of Set 9 | ewa beach
# Processing Record 16 of Set 9 | charcas
# Processing Record 17 of Set 9 | tottori
# Processing Record 18 of Set 9 | tenosique
# Processing Record 19 of Set 9 | fort saint james
# Processing Record 20 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | kyzyl-suu
# Processing Record 22 of Set 9 | dingle
# Processing Record 23 of Set 9 | lichinga
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | pokhara
# Processing Record 27 of Set 9 | asau
# Processing Record 28 of Set 9 | jacareacanga
# Processing Record 29 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 30 of Set 9 | havoysund
# Processing Record 31 of Set 9 | neder vindinge
# Processing Record 32 of Set 9 | hauterive
# Processing Record 33 of Set 9 | ruteng
# Processing Record 34 of Set 9 | medea
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 9 | batagay-alyta
# Processing Record 38 of Set 9 | kavaratti
# Processing Record 39 of Set 9 | chengde
# Processing Record 40 of Set 9 | chara
# Processing Record 41 of Set 9 | upington
# Processing Record 42 of Set 9 | paramirim
# Processing Record 43 of Set 9 | ramganj mandi
# Processing Record 44 of Set 9 | mnogovershinnyy
# Processing Record 45 of Set 9 | cabo san lucas
# Processing Record 46 of Set 9 | rantepao
# Processing Record 47 of Set 9 | qasigiannguit
# Processing Record 48 of Set 9 | torbay
# Processing Record 49 of Set 9 | zaraza
# Processing Record 50 of Set 9 | price
# Processing Record 1 of Set 10 | balezino
# Processing Record 2 of Set 10 | toora-khem
# Processing Record 3 of Set 10 | bose
# Processing Record 4 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 5 of Set 10 | ola
# Processing Record 6 of Set 10 | nishihara
# Processing Record 7 of Set 10 | ostrovnoy
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | taoudenni
# Processing Record 10 of Set 10 | chazuta
# Processing Record 11 of Set 10 | pitimbu
# Processing Record 12 of Set 10 | havelock
# Processing Record 13 of Set 10 | yendi
# Processing Record 14 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 10 | hoquiam
# Processing Record 16 of Set 10 | sisimiut
# Processing Record 17 of Set 10 | manaure
# Processing Record 18 of Set 10 | mahajanga
# Processing Record 19 of Set 10 | dubai
# Processing Record 20 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 10 | sobolevo
# Processing Record 22 of Set 10 | hay river
# Processing Record 23 of Set 10 | harwich
# Processing Record 24 of Set 10 | bayonet point
# Processing Record 25 of Set 10 | coquimbo
# Processing Record 26 of Set 10 | kawalu
# Processing Record 27 of Set 10 | gushikawa
# Processing Record 28 of Set 10 | zhigansk
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | atambua
# Processing Record 31 of Set 10 | kloulklubed
# Processing Record 32 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 10 | northam
# Processing Record 34 of Set 10 | istria
# Processing Record 35 of Set 10 | cidreira
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | erdenet
# Processing Record 38 of Set 10 | kochi
# Processing Record 39 of Set 10 | sorland
# Processing Record 40 of Set 10 | damaturu
# Processing Record 41 of Set 10 | puerto leguizamo
# Processing Record 42 of Set 10 | kassala
# Processing Record 43 of Set 10 | nalut
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | morgan city
# Processing Record 46 of Set 10 | okhotsk
# Processing Record 47 of Set 10 | abapo
# Processing Record 48 of Set 10 | strazske
# Processing Record 49 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 10 | mirnyy
# Processing Record 1 of Set 11 | almaty
# Processing Record 2 of Set 11 | farafangana
# Processing Record 3 of Set 11 | palmerston north
# Processing Record 4 of Set 11 | harer
# Processing Record 5 of Set 11 | san patricio
# Processing Record 6 of Set 11 | lorengau
# Processing Record 7 of Set 11 | salinas
# Processing Record 8 of Set 11 | pafos
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | vila franca do campo
# Processing Record 11 of Set 11 | mpika
# Processing Record 12 of Set 11 | borovskoy
# Processing Record 13 of Set 11 | biograd na moru
# Processing Record 14 of Set 11 | sitka
# Processing Record 15 of Set 11 | chifeng
# Processing Record 16 of Set 11 | agirish
# Processing Record 17 of Set 11 | vanavara
# Processing Record 18 of Set 11 | lighthouse point
# Processing Record 19 of Set 11 | genhe
# Processing Record 20 of Set 11 | obo
# Processing Record 21 of Set 11 | baruun-urt
# Processing Record 22 of Set 11 | souillac
# Processing Record 23 of Set 11 | ilovita
# Processing Record 24 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 11 | bobonong
# City not found. Skipping...
# Processing Record 27 of Set 11 | palestine
# Processing Record 28 of Set 11 | hidalgotitlan
# Processing Record 29 of Set 11 | samagaltay
# Processing Record 30 of Set 11 | kholtoson
# Processing Record 31 of Set 11 | sangin
# Processing Record 32 of Set 11 | smolenka
# Processing Record 33 of Set 11 | hue
# Processing Record 34 of Set 11 | vagur
# Processing Record 35 of Set 11 | alghero
# Processing Record 36 of Set 11 | kenai
# Processing Record 37 of Set 11 | kibre mengist
# Processing Record 38 of Set 11 | shache
# Processing Record 39 of Set 11 | lujan
# Processing Record 40 of Set 11 | phalombe
# Processing Record 41 of Set 11 | aiken
# Processing Record 42 of Set 11 | kita
# Processing Record 43 of Set 11 | portland
# Processing Record 44 of Set 11 | manta
# Processing Record 45 of Set 11 | santa maria
# Processing Record 46 of Set 11 | nyuksenitsa
# Processing Record 47 of Set 11 | flinders
# Processing Record 48 of Set 11 | mormugao
# Processing Record 49 of Set 11 | ankazoabo
# Processing Record 50 of Set 11 | lensk
# Processing Record 1 of Set 12 | krasnyy chikoy
# Processing Record 2 of Set 12 | milkovo
# Processing Record 3 of Set 12 | arlit
# Processing Record 4 of Set 12 | kiunga
# Processing Record 5 of Set 12 | scarborough
# Processing Record 6 of Set 12 | chadiza
# Processing Record 7 of Set 12 | krasnaya gora
# Processing Record 8 of Set 12 | orange cove
# Processing Record 9 of Set 12 | miram shah
# Processing Record 10 of Set 12 | buritis
# Processing Record 11 of Set 12 | ekibastuz
# Processing Record 12 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 13 of Set 12 | rio grande
# Processing Record 14 of Set 12 | chanika
# Processing Record 15 of Set 12 | bealanana
# Processing Record 16 of Set 12 | krasnovishersk
# Processing Record 17 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 18 of Set 12 | nouadhibou
# Processing Record 19 of Set 12 | arandis
# Processing Record 20 of Set 12 | shunyi
# Processing Record 21 of Set 12 | half moon bay
# Processing Record 22 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 12 | doha
# Processing Record 24 of Set 12 | vaitape
# Processing Record 25 of Set 12 | vidor
# Processing Record 26 of Set 12 | akniste
# Processing Record 27 of Set 12 | batagay
# Processing Record 28 of Set 12 | kenora
# Processing Record 29 of Set 12 | ubeda
# Processing Record 30 of Set 12 | sakaiminato
# Processing Record 31 of Set 12 | pedernales
# Processing Record 32 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 12 | floresta
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | badaojiang
# City not found. Skipping...
# Processing Record 36 of Set 12 | celestun
# Processing Record 37 of Set 12 | ternate
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | taman
# Processing Record 40 of Set 12 | sept-iles
# Processing Record 41 of Set 12 | tra vinh
# Processing Record 42 of Set 12 | togur
# Processing Record 43 of Set 12 | imbituba
# Processing Record 44 of Set 12 | yantal
# Processing Record 45 of Set 12 | magadan
# Processing Record 46 of Set 12 | hollola
# Processing Record 47 of Set 12 | college
# Processing Record 48 of Set 12 | terra rica
# Processing Record 49 of Set 12 | ngaoundere
# Processing Record 50 of Set 12 | baykit
# Processing Record 1 of Set 13 | aksarka
# Processing Record 2 of Set 13 | araouane
# Processing Record 3 of Set 13 | buenos aires
# Processing Record 4 of Set 13 | galveston
# Processing Record 5 of Set 13 | sangar
# Processing Record 6 of Set 13 | opuwo
# Processing Record 7 of Set 13 | svetlogorsk
# Processing Record 8 of Set 13 | sao raimundo nonato
# Processing Record 9 of Set 13 | awbari
# Processing Record 10 of Set 13 | mikhaylovsk
# Processing Record 11 of Set 13 | honiara
# Processing Record 12 of Set 13 | nisia floresta
# Processing Record 13 of Set 13 | embonas
# Processing Record 14 of Set 13 | la ronge
# Processing Record 15 of Set 13 | shieli
# Processing Record 16 of Set 13 | matay
# Processing Record 17 of Set 13 | linxia
# Processing Record 18 of Set 13 | soyo
# Processing Record 19 of Set 13 | sao borja
# Processing Record 20 of Set 13 | eyl
# Processing Record 21 of Set 13 | narsaq
# Processing Record 22 of Set 13 | hinton
# Processing Record 23 of Set 13 | luderitz
# Processing Record 24 of Set 13 | biltine
# Processing Record 25 of Set 13 | sidi ali
# Processing Record 26 of Set 13 | casper
# Processing Record 27 of Set 13 | gat
# Processing Record 28 of Set 13 | hattiesburg
# Processing Record 29 of Set 13 | curumani
# Processing Record 30 of Set 13 | belaya gora
# Processing Record 31 of Set 13 | sao miguel do guama
# Processing Record 32 of Set 13 | tautira
# Processing Record 33 of Set 13 | agua verde
# Processing Record 34 of Set 13 | camacha
# Processing Record 35 of Set 13 | kokoda
# Processing Record 36 of Set 13 | te anau
# Processing Record 37 of Set 13 | taunggyi
# Processing Record 38 of Set 13 | mount gambier
# Processing Record 39 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | awjilah
# Processing Record 41 of Set 13 | otradnoye
# Processing Record 42 of Set 13 | tiznit
# Processing Record 43 of Set 13 | krionerion
# City not found. Skipping...
# Processing Record 44 of Set 13 | boulder city
# Processing Record 45 of Set 13 | tanabe
# Processing Record 46 of Set 13 | otukpo
# Processing Record 47 of Set 13 | buala
# Processing Record 48 of Set 13 | oil city
# Processing Record 49 of Set 13 | kautokeino
# Processing Record 50 of Set 13 | nador
# Processing Record 1 of Set 14 | khandyga
# Processing Record 2 of Set 14 | lagoa
# Processing Record 3 of Set 14 | huarmey
# Processing Record 4 of Set 14 | las palmas
# Processing Record 5 of Set 14 | tambovka
# Processing Record 6 of Set 14 | kingaroy
# Processing Record 7 of Set 14 | manadhoo
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | hongan
# City not found. Skipping...
# Processing Record 10 of Set 14 | sebastian
# Processing Record 11 of Set 14 | bramming
# Processing Record 12 of Set 14 | la uribe
# City not found. Skipping...
# Processing Record 13 of Set 14 | rabo de peixe
# Processing Record 14 of Set 14 | springbok
# Processing Record 15 of Set 14 | kuytun
# Processing Record 16 of Set 14 | saint-paul
# Processing Record 17 of Set 14 | north bend
# Processing Record 18 of Set 14 | lucea
# Processing Record 19 of Set 14 | gibara
# Processing Record 20 of Set 14 | songjianghe
# Processing Record 21 of Set 14 | miracema do tocantins
# Processing Record 22 of Set 14 | kingsport
# Processing Record 23 of Set 14 | margate
# Processing Record 24 of Set 14 | novorzhev
# Processing Record 25 of Set 14 | vanimo
# Processing Record 26 of Set 14 | shimoga
# Processing Record 27 of Set 14 | semnan
# Processing Record 28 of Set 14 | mukhen
# Processing Record 29 of Set 14 | champerico
# Processing Record 30 of Set 14 | noumea
# Processing Record 31 of Set 14 | iqaluit
# Processing Record 32 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 33 of Set 14 | urucara
# Processing Record 34 of Set 14 | kamien pomorski
# Processing Record 35 of Set 14 | carballo
# Processing Record 36 of Set 14 | kashi
# Processing Record 37 of Set 14 | ipoti
# Processing Record 38 of Set 14 | carmo do rio claro
# Processing Record 39 of Set 14 | jinchang
# Processing Record 40 of Set 14 | erzin
# Processing Record 41 of Set 14 | manjacaze
# Processing Record 42 of Set 14 | komsomolskiy
# Processing Record 43 of Set 14 | simbahan
# Processing Record 44 of Set 14 | asfi
# Processing Record 45 of Set 14 | sitges
# Processing Record 46 of Set 14 | tari
# Processing Record 47 of Set 14 | mandera
# Processing Record 48 of Set 14 | kalmunai
# Processing Record 49 of Set 14 | abu samrah
# Processing Record 50 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 15 | micheweni
# Processing Record 2 of Set 15 | general roca
# Processing Record 3 of Set 15 | methven
# Processing Record 4 of Set 15 | cleveland
# Processing Record 5 of Set 15 | port hedland
# Processing Record 6 of Set 15 | puerto escondido
# Processing Record 7 of Set 15 | valparaiso
# Processing Record 8 of Set 15 | mizdah
# Processing Record 9 of Set 15 | kutum
# Processing Record 10 of Set 15 | linguere
# Processing Record 11 of Set 15 | krasnoselkup
# Processing Record 12 of Set 15 | mount vernon
# Processing Record 13 of Set 15 | manokwari
# Processing Record 14 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 15 | nha trang
# Processing Record 16 of Set 15 | korla
# Processing Record 17 of Set 15 | kang
# Processing Record 18 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 19 of Set 15 | dabakala
# Processing Record 20 of Set 15 | ravar
# Processing Record 21 of Set 15 | hobyo
# Processing Record 22 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 15 | fort-shevchenko
# Processing Record 24 of Set 15 | bemidji
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | tarrafal
# Processing Record 27 of Set 15 | porgera
# Processing Record 28 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 15 | toribio
# Processing Record 30 of Set 15 | darhan
# Processing Record 31 of Set 15 | werda
# Processing Record 32 of Set 15 | canutama
# Processing Record 33 of Set 15 | luba
# Processing Record 34 of Set 15 | hukuntsi
# Processing Record 35 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 15 | kayerkan
# Processing Record 37 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 15 | deqing
# Processing Record 39 of Set 15 | kuruman
# Processing Record 40 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 15 | walvis bay
# Processing Record 42 of Set 15 | grand-bourg
# Processing Record 43 of Set 15 | kavadarci
# Processing Record 44 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 45 of Set 15 | hounde
# Processing Record 46 of Set 15 | misratah
# Processing Record 47 of Set 15 | burica
# City not found. Skipping...
# Processing Record 48 of Set 15 | kharar
# Processing Record 49 of Set 15 | campbell river
# Processing Record 50 of Set 15 | chicama
# Processing Record 1 of Set 16 | treinta y tres
# Processing Record 2 of Set 16 | presidencia roque saenz pena
# Processing Record 3 of Set 16 | ponnani
# Processing Record 4 of Set 16 | guiyang
# Processing Record 5 of Set 16 | whitehorse
# Processing Record 6 of Set 16 | lata
# Processing Record 7 of Set 16 | chinu
# Processing Record 8 of Set 16 | ucluelet
# Processing Record 9 of Set 16 | manitouwadge
# Processing Record 10 of Set 16 | banda aceh
# Processing Record 11 of Set 16 | ayan
# Processing Record 12 of Set 16 | odweyne
# Processing Record 13 of Set 16 | elizabeth city
# Processing Record 14 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 16 | alekseyevsk
# Processing Record 16 of Set 16 | chegdomyn
# Processing Record 17 of Set 16 | stokmarknes
# Processing Record 18 of Set 16 | itoman
# Processing Record 19 of Set 16 | ust-ilimsk
# Processing Record 20 of Set 16 | osmena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     62.19        86          32        4.00
# 1    Busselton -33.6500  115.3333     70.05        39         100        9.13
# 2         Naze  28.3667  129.4833     67.12        61           9       11.81
# 3     Yangambi   0.8102   24.4336     69.48        99          97        1.79
# 4      Cayenne   4.9333  -52.3333     78.84        89           0        3.44
# 5    Fairbanks  64.8378 -147.7164     15.60        81          40        4.61
# 6        Romny  50.7510   33.4747     34.79        95           6        7.20
# 7    Indramayu  -6.3264  108.3200     81.93        73         100        3.33
# 8        Kapaa  22.0752 -159.3190     80.92        62          20       13.80
# 9       Sabang   5.8933   95.3214     80.64        79         100       21.41
#
#   Country Weather Description
# 0      ZA    scattered clouds
# 1      AU     overcast clouds
# 2      JP           clear sky
# 3      CD          light rain
# 4      GF           clear sky
# 5      US    scattered clouds
# 6      UA           clear sky
# 7      ID          light rain
# 8      US          few clouds
# 9      ID       moderate rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=['City','Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Weather Description']

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Alfred      ZA -33.5906   26.8910     62.19        86          32
# 1    Busselton      AU -33.6500  115.3333     70.05        39         100
# 2         Naze      JP  28.3667  129.4833     67.12        61           9
# 3     Yangambi      CD   0.8102   24.4336     69.48        99          97
# 4      Cayenne      GF   4.9333  -52.3333     78.84        89           0
# 5    Fairbanks      US  64.8378 -147.7164     15.60        81          40
# 6        Romny      UA  50.7510   33.4747     34.79        95           6
# 7    Indramayu      ID  -6.3264  108.3200     81.93        73         100
# 8        Kapaa      US  22.0752 -159.3190     80.92        62          20
# 9       Sabang      ID   5.8933   95.3214     80.64        79         100
#
#    Wind Speed Weather Description
# 0        4.00    scattered clouds
# 1        9.13     overcast clouds
# 2       11.81           clear sky
# 3        1.79          light rain
# 4        3.44           clear sky
# 5        4.61    scattered clouds
# 6        7.20           clear sky
# 7        3.33          light rain
# 8       13.80          few clouds
# 9       21.41       moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
