# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#Create random latitudes & longitudes
lats=np.random.uniform(-90, 90, size=1500)
lngs=np.random.uniform(-180, 180, size=1500)
lats_lngs=zip(lats, lngs)
lats_lngs

# %%
coordinates=list(lats_lngs)

# %%
#get unique cities
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 600

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + " ".join(city.split())

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | zhuozhou
# City not found. Skipping...
# Processing Record 3 of Set 1 | riyadh
# Processing Record 4 of Set 1 | vanderhoof
# Processing Record 5 of Set 1 | amahai
# Processing Record 6 of Set 1 | poceirao
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | eureka
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | grande prairie
# Processing Record 15 of Set 1 | pembroke
# Processing Record 16 of Set 1 | andenes
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | westport
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | pietarsaari
# Processing Record 25 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | yarmouth
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | vila
# Processing Record 34 of Set 1 | maxixe
# Processing Record 35 of Set 1 | acuna
# City not found. Skipping...
# Processing Record 36 of Set 1 | xucheng
# Processing Record 37 of Set 1 | vostok
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | sola
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | saint-augustin
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | zabolottya
# City not found. Skipping...
# Processing Record 49 of Set 1 | ibra
# Processing Record 50 of Set 1 | ulundi
# Processing Record 1 of Set 2 | yar-sale
# Processing Record 2 of Set 2 | moerai
# Processing Record 3 of Set 2 | padang
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | riaba
# City not found. Skipping...
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | gijon
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | muskogee
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | sabibah
# City not found. Skipping...
# Processing Record 21 of Set 2 | vestmannaeyjar
# Processing Record 22 of Set 2 | neuquen
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | ponta delgada
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | joensuu
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | ghanzi
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | straumen
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | puerto baquerizo moreno
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | whitianga
# Processing Record 44 of Set 2 | alyangula
# Processing Record 45 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | svetlogorsk
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | marrakesh
# Processing Record 3 of Set 3 | sistranda
# Processing Record 4 of Set 3 | hualmay
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | chom bung
# City not found. Skipping...
# Processing Record 7 of Set 3 | bowen
# Processing Record 8 of Set 3 | saint-michel-des-saints
# Processing Record 9 of Set 3 | hervey bay
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | beringovskiy
# Processing Record 12 of Set 3 | kozhva
# Processing Record 13 of Set 3 | abha
# Processing Record 14 of Set 3 | blackwater
# Processing Record 15 of Set 3 | vanimo
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | olot
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | sambava
# Processing Record 20 of Set 3 | the valley
# Processing Record 21 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 3 | musafirkhana
# Processing Record 23 of Set 3 | sibolga
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 3 | pangody
# Processing Record 27 of Set 3 | takaka
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | liwale
# Processing Record 33 of Set 3 | siuna
# Processing Record 34 of Set 3 | ekhabi
# Processing Record 35 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | lasa
# Processing Record 37 of Set 3 | purpe
# Processing Record 38 of Set 3 | kisumu
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | bullingen
# City not found. Skipping...
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | bereda
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | grand forks
# Processing Record 45 of Set 3 | carauari
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | sur
# Processing Record 3 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 4 | san rafael
# Processing Record 5 of Set 4 | isangel
# Processing Record 6 of Set 4 | ierapetra
# Processing Record 7 of Set 4 | bullhead city
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | sinnamary
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | urucara
# Processing Record 13 of Set 4 | kosonsoy
# Processing Record 14 of Set 4 | rio grande
# Processing Record 15 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint-francois
# Processing Record 17 of Set 4 | trincomalee
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | ampanihy
# Processing Record 20 of Set 4 | atyrau
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | bisira
# Processing Record 24 of Set 4 | bonthe
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | asfi
# Processing Record 27 of Set 4 | agva
# City not found. Skipping...
# Processing Record 28 of Set 4 | kawalu
# Processing Record 29 of Set 4 | sao geraldo do araguaia
# Processing Record 30 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 4 | pangnirtung
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | san jose
# Processing Record 34 of Set 4 | abapo
# Processing Record 35 of Set 4 | haines junction
# Processing Record 36 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 4 | sampit
# Processing Record 38 of Set 4 | lantawan
# Processing Record 39 of Set 4 | powell river
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | manokwari
# Processing Record 42 of Set 4 | mutare
# Processing Record 43 of Set 4 | saint anthony
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | salon-de-provence
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | mezen
# Processing Record 50 of Set 4 | faya
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | ust-nera
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | vaitape
# Processing Record 5 of Set 5 | marystown
# Processing Record 6 of Set 5 | rurrenabaque
# Processing Record 7 of Set 5 | caucaia
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | ridgecrest
# Processing Record 10 of Set 5 | coari
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | husavik
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | irbeyskoye
# Processing Record 17 of Set 5 | cherskiy
# Processing Record 18 of Set 5 | kaabong
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | kavaratti
# Processing Record 21 of Set 5 | kikwit
# Processing Record 22 of Set 5 | verkhnevilyuysk
# Processing Record 23 of Set 5 | obihiro
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | biak
# Processing Record 26 of Set 5 | safaga
# Processing Record 27 of Set 5 | chuy
# Processing Record 28 of Set 5 | promysla
# City not found. Skipping...
# Processing Record 29 of Set 5 | jorhat
# Processing Record 30 of Set 5 | tautira
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | illela
# Processing Record 33 of Set 5 | morant bay
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | arlit
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | kushmurun
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 40 of Set 5 | basoko
# Processing Record 41 of Set 5 | iquitos
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | north bend
# Processing Record 44 of Set 5 | espirito santo do pinhal
# Processing Record 45 of Set 5 | zhigansk
# Processing Record 46 of Set 5 | kharan
# Processing Record 47 of Set 5 | porto velho
# Processing Record 48 of Set 5 | poum
# Processing Record 49 of Set 5 | ilulissat
# Processing Record 50 of Set 5 | makung
# City not found. Skipping...
# Processing Record 1 of Set 6 | cravo norte
# Processing Record 2 of Set 6 | bolobo
# Processing Record 3 of Set 6 | imbituba
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | clocolan
# Processing Record 6 of Set 6 | zabaykalsk
# Processing Record 7 of Set 6 | alice springs
# Processing Record 8 of Set 6 | cabo san lucas
# Processing Record 9 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 6 | tabou
# Processing Record 11 of Set 6 | san angelo
# Processing Record 12 of Set 6 | orguz
# Processing Record 13 of Set 6 | sisimiut
# Processing Record 14 of Set 6 | barinitas
# Processing Record 15 of Set 6 | yinchuan
# Processing Record 16 of Set 6 | waspan
# Processing Record 17 of Set 6 | chimoio
# Processing Record 18 of Set 6 | pangkalanbuun
# Processing Record 19 of Set 6 | russellville
# Processing Record 20 of Set 6 | tuatapere
# Processing Record 21 of Set 6 | jalu
# Processing Record 22 of Set 6 | biloela
# Processing Record 23 of Set 6 | fort nelson
# Processing Record 24 of Set 6 | korla
# Processing Record 25 of Set 6 | pandharpur
# Processing Record 26 of Set 6 | faanui
# Processing Record 27 of Set 6 | siavonga
# Processing Record 28 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 6 | makaryev
# Processing Record 30 of Set 6 | elkton
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | san patricio
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 6 | muzaffarabad
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | lieksa
# Processing Record 39 of Set 6 | savinka
# Processing Record 40 of Set 6 | vysokogornyy
# Processing Record 41 of Set 6 | antofagasta
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | pangai
# Processing Record 45 of Set 6 | lebu
# Processing Record 46 of Set 6 | show low
# Processing Record 47 of Set 6 | palmas
# Processing Record 48 of Set 6 | teresina
# Processing Record 49 of Set 6 | pilar
# Processing Record 50 of Set 6 | harbour breton
# Processing Record 1 of Set 7 | masterton
# Processing Record 2 of Set 7 | dabakala
# Processing Record 3 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 4 of Set 7 | nanyamba
# Processing Record 5 of Set 7 | sivas
# Processing Record 6 of Set 7 | shimanovsk
# Processing Record 7 of Set 7 | muroto
# Processing Record 8 of Set 7 | severo-yeniseyskiy
# Processing Record 9 of Set 7 | athabasca
# Processing Record 10 of Set 7 | rio gallegos
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | sagarejo
# Processing Record 13 of Set 7 | inhambane
# Processing Record 14 of Set 7 | effium
# Processing Record 15 of Set 7 | abu samrah
# Processing Record 16 of Set 7 | otane
# Processing Record 17 of Set 7 | coahuayana
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | loreto
# Processing Record 20 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 7 | banjar
# Processing Record 22 of Set 7 | zemetchino
# Processing Record 23 of Set 7 | saint-pierre
# Processing Record 24 of Set 7 | ossora
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 7 | ambilobe
# Processing Record 29 of Set 7 | den helder
# Processing Record 30 of Set 7 | nemuro
# Processing Record 31 of Set 7 | ginda
# Processing Record 32 of Set 7 | dudinka
# Processing Record 33 of Set 7 | monte alegre de minas
# Processing Record 34 of Set 7 | monrovia
# Processing Record 35 of Set 7 | mana
# Processing Record 36 of Set 7 | scarborough
# Processing Record 37 of Set 7 | montepuez
# Processing Record 38 of Set 7 | ous
# Processing Record 39 of Set 7 | saint-joseph
# Processing Record 40 of Set 7 | kandi
# Processing Record 41 of Set 7 | payson
# Processing Record 42 of Set 7 | santa cruz de tenerife
# Processing Record 43 of Set 7 | montrose
# Processing Record 44 of Set 7 | toronto
# Processing Record 45 of Set 7 | kapoeta
# Processing Record 46 of Set 7 | corrales
# Processing Record 47 of Set 7 | ixtapa
# Processing Record 48 of Set 7 | jiuquan
# Processing Record 49 of Set 7 | alta floresta
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 8 | smalininkai
# Processing Record 3 of Set 8 | buenavista
# Processing Record 4 of Set 8 | dukat
# Processing Record 5 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 8 | rovenki
# Processing Record 7 of Set 8 | santa barbara
# Processing Record 8 of Set 8 | arkhara
# Processing Record 9 of Set 8 | ambon
# Processing Record 10 of Set 8 | zeya
# Processing Record 11 of Set 8 | auki
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | mudgee
# Processing Record 14 of Set 8 | salinopolis
# Processing Record 15 of Set 8 | broken hill
# Processing Record 16 of Set 8 | lata
# Processing Record 17 of Set 8 | jaru
# Processing Record 18 of Set 8 | sombrio
# Processing Record 19 of Set 8 | rincon
# Processing Record 20 of Set 8 | griffith
# Processing Record 21 of Set 8 | manggar
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | goderich
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | kirakira
# Processing Record 27 of Set 8 | codrington
# Processing Record 28 of Set 8 | nicolas de pierola
# Processing Record 29 of Set 8 | souillac
# Processing Record 30 of Set 8 | yarim
# Processing Record 31 of Set 8 | kruisfontein
# Processing Record 32 of Set 8 | adre
# Processing Record 33 of Set 8 | preobrazheniye
# Processing Record 34 of Set 8 | muscat
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | jashpurnagar
# Processing Record 37 of Set 8 | dodge city
# Processing Record 38 of Set 8 | baicheng
# Processing Record 39 of Set 8 | bambanglipuro
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | mantua
# Processing Record 42 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 8 | tala
# Processing Record 44 of Set 8 | egvekinot
# Processing Record 45 of Set 8 | havre-saint-pierre
# Processing Record 46 of Set 8 | estelle
# Processing Record 47 of Set 8 | abu dhabi
# Processing Record 48 of Set 8 | beberibe
# Processing Record 49 of Set 8 | cap malheureux
# Processing Record 50 of Set 8 | severo-kurilsk
# Processing Record 1 of Set 9 | tongsa
# City not found. Skipping...
# Processing Record 2 of Set 9 | san cristobal
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | bouloupari
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | samarai
# Processing Record 9 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 9 | puerto lempira
# Processing Record 11 of Set 9 | luwuk
# Processing Record 12 of Set 9 | menongue
# Processing Record 13 of Set 9 | aberdeen
# Processing Record 14 of Set 9 | karlskrona
# Processing Record 15 of Set 9 | green river
# Processing Record 16 of Set 9 | calama
# Processing Record 17 of Set 9 | shingu
# Processing Record 18 of Set 9 | paracuru
# Processing Record 19 of Set 9 | sembe
# Processing Record 20 of Set 9 | dalton
# Processing Record 21 of Set 9 | assiniboia
# Processing Record 22 of Set 9 | ilhabela
# Processing Record 23 of Set 9 | banjarmasin
# Processing Record 24 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 9 | arsenyev
# Processing Record 26 of Set 9 | angamacutiro
# City not found. Skipping...
# Processing Record 27 of Set 9 | rancho palos verdes
# Processing Record 28 of Set 9 | miracema do tocantins
# Processing Record 29 of Set 9 | kashi
# Processing Record 30 of Set 9 | road town
# Processing Record 31 of Set 9 | dicabisagan
# Processing Record 32 of Set 9 | port macquarie
# Processing Record 33 of Set 9 | temir
# Processing Record 34 of Set 9 | snezhnogorsk
# Processing Record 35 of Set 9 | camacha
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | yen bai
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 9 | shimoda
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | xining
# Processing Record 43 of Set 9 | tarakan
# Processing Record 44 of Set 9 | sinnar
# Processing Record 45 of Set 9 | mangrol
# Processing Record 46 of Set 9 | calabozo
# Processing Record 47 of Set 9 | glauchau
# Processing Record 48 of Set 9 | bosaso
# Processing Record 49 of Set 9 | miraflores
# Processing Record 50 of Set 9 | aboso
# Processing Record 1 of Set 10 | hedaru
# Processing Record 2 of Set 10 | hastings
# Processing Record 3 of Set 10 | vyartsilya
# Processing Record 4 of Set 10 | inuvik
# Processing Record 5 of Set 10 | luena
# Processing Record 6 of Set 10 | kyabe
# Processing Record 7 of Set 10 | iqaluit
# Processing Record 8 of Set 10 | radhanpur
# Processing Record 9 of Set 10 | antalaha
# Processing Record 10 of Set 10 | champerico
# Processing Record 11 of Set 10 | bordighera
# Processing Record 12 of Set 10 | florianopolis
# Processing Record 13 of Set 10 | marsh harbour
# Processing Record 14 of Set 10 | bonavista
# Processing Record 15 of Set 10 | halifax
# Processing Record 16 of Set 10 | turbat
# Processing Record 17 of Set 10 | humaita
# Processing Record 18 of Set 10 | sanming
# Processing Record 19 of Set 10 | nalut
# Processing Record 20 of Set 10 | lompoc
# Processing Record 21 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | teahupoo
# Processing Record 23 of Set 10 | vetlanda
# Processing Record 24 of Set 10 | isabela
# Processing Record 25 of Set 10 | moose factory
# Processing Record 26 of Set 10 | dombarovskiy
# Processing Record 27 of Set 10 | taywarah
# Processing Record 28 of Set 10 | tarnogskiy gorodok
# Processing Record 29 of Set 10 | hornepayne
# Processing Record 30 of Set 10 | nainpur
# Processing Record 31 of Set 10 | el alto
# Processing Record 32 of Set 10 | zilair
# Processing Record 33 of Set 10 | dingle
# Processing Record 34 of Set 10 | granada
# Processing Record 35 of Set 10 | magistralnyy
# Processing Record 36 of Set 10 | grand-santi
# Processing Record 37 of Set 10 | bundaberg
# Processing Record 38 of Set 10 | dubai
# Processing Record 39 of Set 10 | diego de almagro
# Processing Record 40 of Set 10 | kupang
# Processing Record 41 of Set 10 | sao filipe
# Processing Record 42 of Set 10 | ketchikan
# Processing Record 43 of Set 10 | san-pedro
# Processing Record 44 of Set 10 | novobirilyussy
# Processing Record 45 of Set 10 | berlevag
# Processing Record 46 of Set 10 | xinmin
# Processing Record 47 of Set 10 | grand-lahou
# Processing Record 48 of Set 10 | paragominas
# Processing Record 49 of Set 10 | devonport
# Processing Record 50 of Set 10 | vegueta
# Processing Record 1 of Set 11 | linkou
# Processing Record 2 of Set 11 | harrison
# Processing Record 3 of Set 11 | namatanai
# Processing Record 4 of Set 11 | dakar
# Processing Record 5 of Set 11 | saint-leu
# Processing Record 6 of Set 11 | mendi
# Processing Record 7 of Set 11 | rijeka
# Processing Record 8 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 11 | chuguyevka
# Processing Record 10 of Set 11 | windhoek
# Processing Record 11 of Set 11 | pipar
# Processing Record 12 of Set 11 | matagami
# Processing Record 13 of Set 11 | bhinga
# Processing Record 14 of Set 11 | vlakhokerasea
# City not found. Skipping...
# Processing Record 15 of Set 11 | shaoxing
# Processing Record 16 of Set 11 | puerto padre
# Processing Record 17 of Set 11 | port hedland
# Processing Record 18 of Set 11 | bodden town
# Processing Record 19 of Set 11 | bandarbeyla
# Processing Record 20 of Set 11 | bayan
# Processing Record 21 of Set 11 | shelburne
# Processing Record 22 of Set 11 | caravelas
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | lodja
# Processing Record 25 of Set 11 | punta alta
# Processing Record 26 of Set 11 | atasu
# Processing Record 27 of Set 11 | barra patuca
# Processing Record 28 of Set 11 | hede
# Processing Record 29 of Set 11 | anloga
# Processing Record 30 of Set 11 | zhicheng
# Processing Record 31 of Set 11 | lunca
# Processing Record 32 of Set 11 | santa cruz
# Processing Record 33 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 11 | togur
# Processing Record 35 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 11 | karlshamn
# Processing Record 37 of Set 11 | podgornoye
# Processing Record 38 of Set 11 | harper
# Processing Record 39 of Set 11 | zelenoborskiy
# Processing Record 40 of Set 11 | bara
# Processing Record 41 of Set 11 | sakakah
# Processing Record 42 of Set 11 | solnechnyy
# Processing Record 43 of Set 11 | srivardhan
# Processing Record 44 of Set 11 | tommot
# Processing Record 45 of Set 11 | gambissara
# Processing Record 46 of Set 11 | honiara
# Processing Record 47 of Set 11 | cabedelo
# Processing Record 48 of Set 11 | oxford
# Processing Record 49 of Set 11 | krasnoarmeysk
# Processing Record 50 of Set 11 | richards bay
# Processing Record 1 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 12 | huambo
# Processing Record 3 of Set 12 | sao felix do xingu
# Processing Record 4 of Set 12 | geelong
# Processing Record 5 of Set 12 | mildura
# Processing Record 6 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 12 | sheopur
# Processing Record 8 of Set 12 | maragogi
# Processing Record 9 of Set 12 | shache
# Processing Record 10 of Set 12 | sioux lookout
# Processing Record 11 of Set 12 | labuhan
# Processing Record 12 of Set 12 | baturaja
# Processing Record 13 of Set 12 | tilichiki
# Processing Record 14 of Set 12 | praia da vitoria
# Processing Record 15 of Set 12 | methoni
# Processing Record 16 of Set 12 | puerto carreno
# Processing Record 17 of Set 12 | miles city
# Processing Record 18 of Set 12 | safita
# Processing Record 19 of Set 12 | toamasina
# Processing Record 20 of Set 12 | kigoma
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | karymskoye
# Processing Record 23 of Set 12 | nokaneng
# Processing Record 24 of Set 12 | mungwi
# Processing Record 25 of Set 12 | rawson
# Processing Record 26 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 12 | jacareacanga
# Processing Record 28 of Set 12 | kargasok
# Processing Record 29 of Set 12 | manaure
# Processing Record 30 of Set 12 | hudson
# Processing Record 31 of Set 12 | boma
# Processing Record 32 of Set 12 | ardesen
# Processing Record 33 of Set 12 | olinda
# Processing Record 34 of Set 12 | sorland
# Processing Record 35 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | kpandae
# Processing Record 37 of Set 12 | totma
# Processing Record 38 of Set 12 | ucluelet
# Processing Record 39 of Set 12 | mugur-aksy
# Processing Record 40 of Set 12 | copiapo
# Processing Record 41 of Set 12 | polyarnyye zori
# Processing Record 42 of Set 12 | tura
# Processing Record 43 of Set 12 | bria
# Processing Record 44 of Set 12 | hovd
# Processing Record 45 of Set 12 | ulaangom
# Processing Record 46 of Set 12 | shuangyang
# Processing Record 47 of Set 12 | nazareno
# Processing Record 48 of Set 12 | phaltan
# Processing Record 49 of Set 12 | alabaster
# Processing Record 50 of Set 12 | aykhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 546

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux -20.3428   57.7575     71.85        64          40
# 1           Riyadh  24.6877   46.7219     77.14        24           0
# 2       Vanderhoof  54.0166 -124.0198     28.08        90         100
# 3           Amahai  -3.3333  128.9167     79.72        81          94
# 4         Poceirao  38.8310   -8.7937     63.54        91         100
# 5      East London -33.0153   27.9116     67.14        82          40
# 6         Bengkulu  -3.8004  102.2655     75.54        87         100
# 7      Port Alfred -33.5906   26.8910     65.17        87          94
# 8         Hamilton  39.1834  -84.5333     43.00        79         100
# 9           Eureka  40.8021 -124.1637     48.25       100           0
#
#    Wind Speed Country                 Date
# 0        6.91      MU  2022-11-15 17:54:25
# 1        8.86      SA  2022-11-15 17:52:40
# 2        1.07      CA  2022-11-15 17:54:26
# 3        2.91      ID  2022-11-15 17:54:27
# 4        7.52      PT  2022-11-15 17:54:27
# 5       11.50      ZA  2022-11-15 17:54:27
# 6        8.81      ID  2022-11-15 17:54:28
# 7        7.00      ZA  2022-11-15 17:54:28
# 8        1.99      US  2022-11-15 17:52:07
# 9        1.01      US  2022-11-15 17:50:16

# %%
new_column_order = ["City","Country", "Date", "Lat","Lng",  "Max Temp", "Humidity", "Cloudiness", "Wind Speed" ]
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. wind_speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,-20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Maximum Temperature',
                       'Max Temp',(-50,95))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity', '% Humidity',(40,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-50,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', '% Cloudiness',(47,0))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Cloudiness', '% Cloudiness',(-55,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Wind Speed',(-50,35))
